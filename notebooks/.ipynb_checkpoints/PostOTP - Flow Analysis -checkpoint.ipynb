# %% [markdown]
# This experience aims to analyze data produced by PostOTP.
#
# This data is in csv format, and represents a counting of the type of flows for every field in every trace.
#
# Objectives:
#    - Map data to visual charts, etc.
#    - Produce histograms with the data.

# %%
import pandas as pd

# %%
import os

DATA_FOLDER = "/mnt/B6C8BAECC8BAAA4F/André/UC/Tese/Projects/jaime/OpenTracingProcessor/data/"

COMPLETE_DATA_FOLDER = os.path.join(DATA_FOLDER, "csv_maps_complete")
ANOMALOUS_DATA_FOLDER_1 = os.path.join(DATA_FOLDER, "csv_maps_anomalous_time_frame_28.06__14_25__14_35")
ANOMALOUS_DATA_FOLDER_2 = os.path.join(DATA_FOLDER, "csv_maps_anomalous_time_frame_28.06__16_25__16_35")
NON_ANOMALOUS_DATA_FOLDER_1 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_28.06__14_55__15_05")
NON_ANOMALOUS_DATA_FOLDER_2 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_28.06__15_05__15_15")
NON_ANOMALOUS_DATA_FOLDER_3 = os.path.join(DATA_FOLDER, "csv_maps_non_anomalous_time_frame_28.06__15_15__15_25")

COMPLETE_DATA = pd.read_csv(os.path.join(COMPLETE_DATA_FOLDER, "sorted_service_name_flow_types.csv"))

ANOMALOUS_DATA_1 = pd.read_csv(os.path.join(ANOMALOUS_DATA_FOLDER_1, "sorted_service_name_flow_types.csv"))
ANOMALOUS_DATA_2 = pd.read_csv(os.path.join(ANOMALOUS_DATA_FOLDER_2, "sorted_service_name_flow_types.csv"))

NON_ANOMALOUS_DATA_1 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_1, "sorted_service_name_flow_types.csv"))
NON_ANOMALOUS_DATA_2 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_2, "sorted_service_name_flow_types.csv"))
NON_ANOMALOUS_DATA_3 = pd.read_csv(os.path.join(NON_ANOMALOUS_DATA_FOLDER_3, "sorted_service_name_flow_types.csv"))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

def plot_dataframe(df, title, file_name):
    objects = df['flow_type']
    y_pos = np.arange(len(objects))
    performance = df['count']

    plt.bar(y_pos, performance, align='center', alpha=0.5)
    plt.xticks(y_pos, objects)
    plt.xlabel('WorkFlow type')
    plt.ylabel('WorkFlow Count')
    plt.title(title)

    plt.show()
    
    plt..draw()
    plt.savefig(file_name + '.svg', format="svg")

# %%
import itertools

# COMPLETE_DATA.info()
# ANOMALOUS_DATA.info()
# NON_ANOMALOUS_DATA.info()

flow_type_value_set = set(itertools.chain(COMPLETE_DATA['value'], 
                                          ANOMALOUS_DATA_1['value'], 
                                          ANOMALOUS_DATA_2['value'], 
                                          NON_ANOMALOUS_DATA_1['value'],
                                          NON_ANOMALOUS_DATA_2['value'],
                                          NON_ANOMALOUS_DATA_3['value']))

flow_df = pd.DataFrame(flow_type_value_set, columns=['value'])

def flow_indexes(df):
    indexes = list()
    for value in df['value']:
        index = flow_df.loc[flow_df['value'] == value].index.values[0]
        indexes.append(index)
        print('value:', value, 'index:', index)
    return indexes

COMPLETE_DATA['flow_type'] = flow_indexes(COMPLETE_DATA)
ANOMALOUS_DATA_1['flow_type'] = flow_indexes(ANOMALOUS_DATA_1)
ANOMALOUS_DATA_2['flow_type'] = flow_indexes(ANOMALOUS_DATA_2)
NON_ANOMALOUS_DATA_1['flow_type'] = flow_indexes(NON_ANOMALOUS_DATA_1)
NON_ANOMALOUS_DATA_2['flow_type'] = flow_indexes(NON_ANOMALOUS_DATA_2)
NON_ANOMALOUS_DATA_3['flow_type'] = flow_indexes(NON_ANOMALOUS_DATA_3)
    
# print(COMPLETE_DATA)
# print(ANOMALOUS_DATA)
# print(NON_ANOMALOUS_DATA_1)
# print(NON_ANOMALOUS_DATA_2)
# print(NON_ANOMALOUS_DATA_3)
# Out:
# value: [api_com[api_com]] index: 755
# value: [api_com] index: 764
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]] index: 255
# value: [api_com[api_com],[neutron-server-cascading]] index: 1257
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]]] index: 765
# value: [api_com[api_com],[api_com]] index: 56
# value: [evs] index: 253
# value: [hss] index: 575
# value: [api_com[api_com],[api_com],[api_com]] index: 469
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[neutron-server-cascading]]]] index: 24
# value: [api_com[api_com],[api_com[nova-api-cascading]]] index: 247
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]]] index: 178
# value: [cluster-manager] index: 142
# value: [batch_console[batch_console]] index: 700
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]]]]] index: 193
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascaded]] index: 860
# value: [hss[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]] index: 1132
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com]] index: 694
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 268
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com]] index: 1085
# value: [api_com[api_com[nova-api-cascading]]] index: 823
# value: [batch_console[batch_console],[nova-api-cascading]] index: 231
# value: [hss[neutron-server-cascading]] index: 1217
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascading]] index: 675
# value: [batch_console[api_com[api_com],[api_com]]] index: 843
# value: [api_com[api_com[api_com]]] index: 399
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com]]],[api_com],[api_com],[api_com]] index: 1147
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded]] index: 280
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 883
# value: [api_com[api_com],[api_com[nova-api-cascading]],[api_com],[api_com],[api_com],[api_com],[api_com]] index: 162
# value: [api_com[api_com[api_com]],[api_com]] index: 254
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1204
# value: [api_com[api_com],[nova-api-cascading]] index: 976
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 348
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading]]] index: 8
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 414
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 1259
# value: [api_com[api_com],[api_com],[neutron-server-cascading]] index: 636
# value: [api_com[api_com],[api_com],[api_com[neutron-server-cascading]]] index: 163
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 951
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]]]]] index: 611
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[nova-api-cascading]],[api_com],[api_com]] index: 407
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]]] index: 1065
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading]]]] index: 1223
# value: [api_com[api_com],[api_com],[api_com[neutron-server-cascading[neutron-server-cascaded]]]] index: 567
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]]]],[neutron-server-cascaded]] index: 688
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1235
# value: [api_com[api_com],[api_com[nova-api-cascading]],[api_com]] index: 798
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 545
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 1084
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 381
# value: [api_com[api_com[api_com]],[api_com[api_com]]] index: 117
# value: [hss[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]] index: 538
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascading[neutron-server-cascaded]]] index: 1195
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 27
# value: [cluster-manager[mysql],[mysql],[mysql]] index: 614
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 687
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com]] index: 797
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 485
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded]] index: 916
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 1254
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 698
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]] index: 332
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 383
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascaded],[neutron-server-cascaded]] index: 691
# value: [api_com[api_com[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com]]],[api_com],[api_com],[api_com]] index: 463
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading]],[api_com],[api_com],[api_com],[api_com]] index: 715
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded]] index: 333
# value: [batch_console[api_com[api_com],[api_com[nova-api-cascading]]]] index: 1091
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascaded]] index: 554
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com]] index: 102
# value: [api_com[api_com[api_com],[api_com[api_com]]],[api_com],[api_com],[api_com]] index: 1165
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1141
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 218
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 145
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascading]] index: 1245
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded]] index: 676
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 746
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]]]],[api_com]] index: 901
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 1089
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 659
# value: [api_com[api_com],[api_com[api_com]],[vpc-service[vpc-service]],[vpc-service[vpc-service],[vpc-service],[vpc-service],[vpc-service]],[api_com]] index: 388
# value: [api_com[vpc-service[vpc-service],[vpc-service]]] index: 726
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 190
# value: [api_com[api_com],[api_com[api_com]],[api_com],[api_com[api_com],[api_com]],[api_com[api_com],[api_com]],[api_com[api_com],[api_com]],[api_com[api_com],[api_com],[api_com]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 479
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]] index: 540
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 484
# value: [api_com[api_com],[api_com],[api_com[neutron-server-cascading[neutron-server-cascaded],[neutron-server-cascaded]]]] index: 337
# value: [api_com[api_com],[nova-api-cascading[nova-api-cascading]]] index: 618
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[neutron-server-cascading],[neutron-server-cascading]] index: 885
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascading],[neutron-server-cascading]] index: 125
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]]] index: 445
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded]] index: 1239
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1164
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 984
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 47
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 725
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1019
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 239
# value: [api_com[api_com[api_com]],[api_com[api_com[neutron-server-cascading]]]] index: 77
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 702
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 38
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 113
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com]] index: 266
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 925
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascading],[cinder-api-cascaded],[cinder-scheduler-cascaded]] index: 285
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 179
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 766
# value: [api_com[api_com],[api_com[api_com]],[api_com],[api_com[api_com],[api_com]],[api_com[api_com],[api_com]],[api_com[api_com],[api_com],[api_com]],[neutron-server-cascading],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 80
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded]] index: 314
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascading],[neutron-server-cascading]] index: 672
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 443
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 747
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 735
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[api_com],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded]]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 683
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 517
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]]] index: 140
# value: [cluster-manager[mysql],[mysql],[mysql],[cluster-manager]] index: 282
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com],[api_com]] index: 121
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 70
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 682
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1022
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 892
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 87
# value: [api_com[api_com[api_com]],[api_com[neutron-server-cascading]]] index: 1101
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 884
# value: [api_com[api_com],[api_com[nova-api-cascading]],[api_com[nova-api-cascading]],[api_com],[api_com],[api_com],[api_com]] index: 1177
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]]]],[neutron-server-cascading]] index: 9
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 861
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1007
# value: [api_com[api_com[api_com[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com],[api_com],[api_com],[api_com],[api_com]]],[api_com],[api_com],[api_com],[api_com],[neutron-server-cascading],[neutron-server-cascading]] index: 531
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded]] index: 606
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 917
# value: [api_com[api_com[api_com],[api_com],[api_com]],[api_com],[api_com[api_com],[api_com]]] index: 1213
# value: [api_com[api_com[api_com]],[api_com],[api_com]] index: 1111
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 417
# value: [api_com[api_com[api_com[neutron-server-cascading]]],[api_com[api_com]]] index: 1247
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[neutron-server-cascaded]] index: 346
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded]]],[cinder-volume-cascaded[cinder-volume-cascaded]]] index: 1122
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 829
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded]] index: 619
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascading],[cinder-api-cascaded],[cinder-api-cascaded]] index: 101
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 380
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[neutron-server-cascading],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 573
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[neutron-server-cascading],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1106
# value: [api_com[api_com[api_com]],[neutron-server-cascaded],[neutron-server-cascaded]] index: 1198
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com],[api_com],[api_com]],[api_com],[api_com],[api_com]] index: 200
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]],[api_com]] index: 107
# value: [api_com[api_com[api_com],[api_com[api_com]]],[api_com],[api_com],[api_com],[neutron-server-cascading]] index: 836
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1158
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 748
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascaded],[neutron-server-cascading],[neutron-server-cascaded],[neutron-server-cascaded]] index: 710
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]]]],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 1096
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascading]] index: 826
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com]] index: 1237
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 515
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[neutron-server-cascading],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 1066
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[vpc-service[vpc-service]],[api_com]] index: 819
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascading],[cinder-api-cascaded],[cinder-api-cascaded]] index: 811
# value: [api_com[api_com],[api_com[api_com]],[vpc-service[vpc-service]],[vpc-service[vpc-service],[vpc-service],[vpc-service],[vpc-service]],[api_com],[api_com],[api_com]] index: 543
# value: [api_com[api_com[api_com]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]]] index: 141
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]],[api_com],[api_com],[api_com]] index: 876
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]]] index: 655
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded]] index: 169
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-scheduler-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 298
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com]] index: 678
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 696
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 822
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 753
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 134
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 908
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 714
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascading]] index: 173
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 987
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]]]] index: 911
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 191
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 1024
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 541
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascading],[neutron-server-cascaded]] index: 330
# value: [api_com[api_com],[api_com[api_com]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com[api_com],[api_com]],[api_com[api_com],[api_com]],[api_com[api_com],[api_com],[api_com]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 621
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 409
# value: [api_com[api_com],[api_com],[api_com],[api_com]] index: 130
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 589
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascading],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 1278
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded]]]] index: 392
# value: [api_com[api_com[api_com[neutron-server-cascading]]],[api_com]] index: 429
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded]] index: 511
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 824
# value: [api_com[api_com],[api_com[neutron-server-cascading],[neutron-server-cascading[neutron-server-cascaded]]]] index: 1218
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 626
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 935
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 20
# value: [api_com[api_com[api_com]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 1142
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 468
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded]] index: 974
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[neutron-server-cascading]] index: 526
# value: [api_com[api_com],[api_com],[api_com],[vpc-service[vpc-service]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[neutron-server-cascaded],[neutron-server-cascaded],[neutron-server-cascaded]] index: 620
# value: [api_com[api_com[api_com]],[api_com],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]]] index: 249
# value: [api_com[api_com],[api_com],[api_com],[neutron-server-cascading[neutron-server-cascaded],[neutron-server-cascaded]]] index: 100
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1113
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1028
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded]] index: 1271
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 293
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded]] index: 623
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 1173
# value: [api_com[api_com],[api_com[nova-api-cascading]],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded]]]] index: 578
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-scheduler-cascaded],[cinder-api-cascaded]] index: 782
# value: [api_com[api_com],[api_com],[cinder-api-cascaded[cinder-scheduler-cascaded]]] index: 489
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com[api_com]],[api_com[api_com[nova-api-cascading]],[api_com],[api_com]],[api_com],[api_com],[api_com[vpc-service[vpc-service],[vpc-service],[vpc-service],[vpc-service]],[api_com],[api_com]],[api_com],[api_com[api_com]],[api_com[api_com]],[api_com],[api_com[api_com]],[api_com[api_com]],[api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com]],[api_com[api_com],[evs[evs],[evs[evs]],[evs[evs],[evs]]],[api_com],[evs[evs],[evs[evs]],[evs[evs]],[evs[evs]]],[api_com],[evs[evs],[evs[evs]],[evs[evs]]]],[api_com],[api_com[api_com],[api_com]],[api_com],[api_com[api_com],[api_com],[evs],[api_com],[evs]],[api_com[evs],[api_com],[evs],[api_com],[evs],[api_com],[api_com],[api_com],[api_com],[evs[evs],[evs],[evs],[evs[evs]],[evs[evs]]],[api_com],[evs[evs],[evs],[evs[evs]],[evs],[evs[evs]],[evs[evs]]]],[api_com[api_com]],[api_com],[api_com],[api_com[api_com],[api_com],[api_com]],[api_com],[api_com[api_com],[api_com]],[api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[neutron-server-cascading],[neutron-server-cascaded],[neutron-server-cascaded]] index: 325
# value: [api_com[api_com],[api_com[api_com]],[api_com],[vpc-service[vpc-service],[vpc-service],[vpc-service],[vpc-service]],[api_com],[api_com],[api_com],[api_com],[api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]],[api_com[api_com]],[api_com[api_com]],[neutron-server-cascading],[neutron-server-cascaded]] index: 289
# value: [api_com[api_com],[api_com],[api_com],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded]]],[neutron-server-cascaded],[neutron-server-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[neutron-server-cascaded]] index: 1266
# value: [api_com[api_com],[api_com],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[neutron-server-cascading],[cinder-api-cascaded],[cinder-api-cascaded]] index: 491
# value: [api_com[api_com],[api_com[nova-api-cascading]],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com[api_com]],[api_com[api_com[nova-api-cascading]],[api_com],[api_com]],[api_com],[api_com],[api_com],[api_com[vpc-service[vpc-service],[vpc-service],[vpc-service],[vpc-service]],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com]],[api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com],[evs[evs],[evs[evs]],[evs[evs]],[evs[evs]]]],[api_com],[api_com[evs]],[api_com[evs],[api_com]],[api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com]],[api_com[api_com]],[api_com],[api_com[api_com]],[api_com[api_com]],[api_com[api_com]],[api_com],[api_com],[api_com[api_com],[api_com]],[api_com[api_com],[api_com]],[api_com],[api_com],[api_com[api_com]],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded]]]],[neutron-server-cascaded],[cinder-scheduler-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded]]]]],[cinder-api-cascaded],[cinder-api-cascaded],[nova-api-cascaded[nova-api-cascaded[nova-api-cascaded]],[neutron-server-cascaded]],[neutron-server-cascading],[nova-api-cascaded[nova-api-cascaded[nova-api-cascaded]],[nova-api-cascaded[nova-api-cascaded[nova-api-cascaded]]]],[nova-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[neutron-server-cascaded],[nova-scheduler-cascaded],[cinder-api-cascaded]] index: 1119
# value: [api_com[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading],[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 783
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]],[api_com[api_com]],[api_com[api_com]],[api_com[api_com],[api_com],[api_com],[api_com]],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com]] index: 184
# value: [api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading]],[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]]]] index: 1
# ...
# value: [api_com[api_com[api_com[api_com],[api_com],[api_com],[api_com],[api_com]],[api_com[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]],[neutron-server-cascading]]]],[api_com[api_com]],[api_com[api_com],[api_com],[api_com],[api_com]],[api_com[api_com[neutron-server-cascading],[neutron-server-cascading]]],[api_com[api_com]]],[api_com],[api_com],[api_com],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded]]],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]]]]],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded]]]]]]]]]]]],[cinder-volume-cascaded[cinder-volume-cascaded],[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded]],[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded[cinder-volume-cascaded]]]]]] index: 1261
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com],[api_com[api_com],[api_com]],[cinder-api-cascaded],[cinder-api-cascaded[cinder-scheduler-cascaded]],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded],[cinder-api-cascaded]] index: 1039
# value: [api_com[api_com],[api_com[nova-api-cascading[nova-api-cascading[nova-api-cascading]]]],[api_com],[api_com[api_com],[api_com],[vpc-service[vpc-service],[vpc-service],[vpc-service],[vpc-service]],[vpc-service[vpc-service]]],[api_com],[api_com[api_com],[api_com[api_com]],[api_com[api_com]]],[api_com],[api_com],[api_com],[neutron-server-cascaded],[neutron-server-cascaded]] index: 615
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 666
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"},{\\\"1\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"neutron-server-cascading\\\\\\\"}\\\"}]}\"}]}"}]} index: 387
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\"}\"}]}"}]} index: 467
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"api_com\"}"}]} index: 310
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"},{\\\"1\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}]}\\\\\\\\\\\\\\\"}]}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 507
# value: {"spanValue":"api_com"} index: 510
# value: {"spanValue":"evs"} index: 488
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"}]} index: 1276
# value: {"spanValue":"cluster-manager","spanChildren":[{"0":"{\"spanValue\":\"mysql\"}"},{"1":"{\"spanValue\":\"mysql\"}"},{"2":"{\"spanValue\":\"mysql\"}"}]} index: 55
# value: {"spanValue":"cluster-manager","spanChildren":[{"0":"{\"spanValue\":\"mysql\"}"},{"1":"{\"spanValue\":\"mysql\"}"},{"2":"{\"spanValue\":\"mysql\"}"},{"3":"{\"spanValue\":\"cluster-manager\"}"}]} index: 207
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"},{\\\"1\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}]}\\\\\\\\\\\\\\\"}]}\\\\\\\"}]}\\\"},{\\\"2\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"neutron-server-cascading\\\\\\\"}\\\"}]}\"}]}"}]} index: 947
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"neutron-server-cascading\"}"}]} index: 1251
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 666
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"},{\\\"1\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}]}\\\\\\\\\\\\\\\"}]}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 507
# value: {"spanValue":"api_com"} index: 510
# value: {"spanValue":"evs"} index: 488
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"}]} index: 1276
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"api_com\"}"}]} index: 310
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"},{\\\"1\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}]}\\\\\\\\\\\\\\\"}]}\\\\\\\"}]}\\\"},{\\\"2\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"neutron-server-cascading\\\\\\\"}\\\"}]}\"}]}"}]} index: 947
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"neutron-server-cascading\"}"}]} index: 1251
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 666
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\"}\"}]}"}]} index: 844
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"},{\\\"1\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\",\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanChildren\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":[{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"0\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"{\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\"}]}\\\\\\\\\\\\\\\"}]}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 507
# value: {"spanValue":"api_com"} index: 510
# value: {"spanValue":"evs"} index: 488
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"}]} index: 1276
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"api_com\"}"}]} index: 310
# value: {"spanValue":"cluster-manager","spanChildren":[{"0":"{\"spanValue\":\"mysql\"}"},{"1":"{\"spanValue\":\"mysql\"}"},{"2":"{\"spanValue\":\"mysql\"}"},{"3":"{\"spanValue\":\"cluster-manager\"}"}]} index: 207
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"},{"1":"{\"spanValue\":\"neutron-server-cascading\"}"}]} index: 1251
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 666
# value: {"spanValue":"api_com"} index: 510
# value: {"spanValue":"evs"} index: 488
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\",\"spanChildren\":[{\"0\":\"{\\\"spanValue\\\":\\\"nova-api-cascading\\\",\\\"spanChildren\\\":[{\\\"0\\\":\\\"{\\\\\\\"spanValue\\\\\\\":\\\\\\\"nova-api-cascading\\\\\\\",\\\\\\\"spanChildren\\\\\\\":[{\\\\\\\"0\\\\\\\":\\\\\\\"{\\\\\\\\\\\\\\\"spanValue\\\\\\\\\\\\\\\":\\\\\\\\\\\\\\\"nova-api-cascading\\\\\\\\\\\\\\\"}\\\\\\\"}]}\\\"}]}\"}]}"}]} index: 666
# value: {"spanValue":"api_com"} index: 510
# value: {"spanValue":"evs"} index: 488
# value: {"spanValue":"api_com","spanChildren":[{"0":"{\"spanValue\":\"api_com\"}"}]} index: 1276

# %% [markdown]
# ### Filter data
#
# In this section, we filter all data by the set of flow types presented in the anomalous and non anomalous data.

# %%
flow_type_index_set = set(itertools.chain(ANOMALOUS_DATA_1['flow_type'], 
                                          ANOMALOUS_DATA_2['flow_type'],
                                          NON_ANOMALOUS_DATA_1['flow_type'],
                                          NON_ANOMALOUS_DATA_2['flow_type'],
                                          NON_ANOMALOUS_DATA_3['flow_type']))

flow_type_index_set = sorted(flow_type_index_set)

FILTERED_COMPLETE_DATA = COMPLETE_DATA[COMPLETE_DATA['flow_type'].isin(flow_type_index_set)]
FILTERED_ANOMALOUS_DATA_1 = ANOMALOUS_DATA_1[ANOMALOUS_DATA_1['flow_type'].isin(flow_type_index_set)]
FILTERED_ANOMALOUS_DATA_2 = ANOMALOUS_DATA_2[ANOMALOUS_DATA_2['flow_type'].isin(flow_type_index_set)]
FILTERED_NON_ANOMALOUS_DATA_1 = NON_ANOMALOUS_DATA_1[NON_ANOMALOUS_DATA_1['flow_type'].isin(flow_type_index_set)]
FILTERED_NON_ANOMALOUS_DATA_2 = NON_ANOMALOUS_DATA_2[NON_ANOMALOUS_DATA_2['flow_type'].isin(flow_type_index_set)]
FILTERED_NON_ANOMALOUS_DATA_3 = NON_ANOMALOUS_DATA_3[NON_ANOMALOUS_DATA_3['flow_type'].isin(flow_type_index_set)]

# %%
maximum = FILTERED_ANOMALOUS_DATA_1.loc[FILTERED_ANOMALOUS_DATA_1['count'].idxmax()]
maximum['value']
# Out:
# '{"spanValue":"api_com","spanChildren":[{"0":"{\\"spanValue\\":\\"api_com\\"}"}]}'

# %% [markdown]
# ### Plot data
#
# Bellow are presented the plots for the completed time frame and some samples of anomalous and non anomalous time frames.
#
# All data is filtered by a set of anomalous and non anomalous flow types. In this way we focus on the specific flows that represent more interest for this analysis.

# %%
#plot_dataframe(FILTERED_COMPLETE_DATA, 'Complete data')
FILTERED_ANOMALOUS_DATA_1 = FILTERED_ANOMALOUS_DATA_1.sort_values(by='count')
FILTERED_ANOMALOUS_DATA_2 = FILTERED_ANOMALOUS_DATA_2.sort_values(by='count')
FILTERED_NON_ANOMALOUS_DATA_2 = FILTERED_NON_ANOMALOUS_DATA_2.sort_values(by='count')
FILTERED_NON_ANOMALOUS_DATA_3 = FILTERED_NON_ANOMALOUS_DATA_3.sort_values(by='count')

#plot_dataframe(FILTERED_ANOMALOUS_DATA_1, 'Sample 1 - \"Anomalous\" time frame 2:25-2:35PM (28.06.2018)')
#plot_dataframe(FILTERED_ANOMALOUS_DATA_2, 'Sample 2 - \"Anomalous\" time frame 4:25-4:35PM (28.06.2018)')
##plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_1, 'Non anomalous data - Sample 1')
#plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_2, 'Sample 3 - \"Non-Anomalous\" time frame 3:05-3:15PM (28.06.2018)')
#plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_3, 'Sample 4 - \"Non-Anomalous\" time frame 3:15-3:25PM (29.06.2018)')

# %%
#plot_dataframe(FILTERED_COMPLETE_DATA, 'Complete data')
FILTERED_ANOMALOUS_DATA_1 = FILTERED_ANOMALOUS_DATA_1.sort_values(by='count')
FILTERED_ANOMALOUS_DATA_2 = FILTERED_ANOMALOUS_DATA_2.sort_values(by='count')
FILTERED_NON_ANOMALOUS_DATA_2 = FILTERED_NON_ANOMALOUS_DATA_2.sort_values(by='count')
FILTERED_NON_ANOMALOUS_DATA_3 = FILTERED_NON_ANOMALOUS_DATA_3.sort_values(by='count')

plot_dataframe(FILTERED_ANOMALOUS_DATA_1, '\"Anomalous\" sample for Service A', 'anomalous_sample_for_service_a')

#plot_dataframe(FILTERED_ANOMALOUS_DATA_2, 'Sample 2 - \"Anomalous\" time frame 4:25-4:35PM (28.06.2018)')
#plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_1, 'Non anomalous data - Sample 1')
#plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_2, '\"Non-Anomalous\" time frame 3:05-3:15PM (28.06.2018)')
plot_dataframe(FILTERED_NON_ANOMALOUS_DATA_3, '\"Non-Anomalous\" sample for Service A', 'non_anomalous_sample_for_service_a')
